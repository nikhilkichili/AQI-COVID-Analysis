# %%
# EDA Analysis on 2020 data vis a vis AQI and Covid Cases
# Import required libraries
import pandas as pd
import numpy as np
import math

#import visualisation libraries
import matplotlib.pyplot as plt
import seaborn as sns

#import Date-Time Libraries
import datetime
import matplotlib.dates as mdates

# %%
# Read the aqi covid files
df_aqi_covid_2020 = pd.read_csv('/Users/nkichili/Desktop/Synopsys/aqi_covid_2020.csv')

# %%
df_aqi_covid_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22536 entries, 0 to 22535
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   co             22536 non-null  float64
#  1   no2            22536 non-null  float64
#  2   o3             22536 non-null  float64
#  3   pm10           22536 non-null  float64
#  4   pm25           22536 non-null  float64
#  5   predicted aqi  22536 non-null  float64
#  6   City           22536 non-null  object
#  7   Date           22536 non-null  object
#  8   county_name    22536 non-null  object
#  9   cases          21328 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 1.7+ MB

# %%
#EDA on 2020 data

# %%
sns.pairplot(df_aqi_covid_2020)

# %%
plt.figure(figsize=(30,8))
sns.barplot(x = df_aqi_covid_2020['City'], y = df_aqi_covid_2020['predicted aqi'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='predicted aqi'>

# %%
plt.figure(figsize=(30,8))
sns.barplot(x = df_aqi_covid_2020['City'], y = df_aqi_covid_2020['cases'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='cases'>

# %%
plt.figure(figsize=(30,8))
sns.barplot(x = df_aqi_covid_2020['county_name'], y = df_aqi_covid_2020['predicted aqi'])
# Out:
# <AxesSubplot:xlabel='county_name', ylabel='predicted aqi'>

# %%
plt.figure(figsize=(30,8))
sns.barplot(x = df_aqi_covid_2020['county_name'], y = df_aqi_covid_2020['cases'])
# Out:
# <AxesSubplot:xlabel='county_name', ylabel='cases'>

# %%
plt.figure(figsize=(30,8))
sns.boxplot(y = df_aqi_covid_2020['predicted aqi'], x = df_aqi_covid_2020['City'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='predicted aqi'>

# %%
plt.figure(figsize=(30,8))
sns.boxplot(y = df_aqi_covid_2020['cases'], x = df_aqi_covid_2020['City'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='cases'>

# %%
#plt.figure(figsize=(30,8))
#sns.lineplot(data=df_aqi_covid_2020.predicted_aqi, color="g")
#ax2 = plt.twinx()
#sns.lineplot(data=df_aqi_covid_2020.cases, color="b", ax=ax2)


#ax = df_aqi_covid_2020.plot(x="City", y="predicted aqi", legend=False)
#ax2 = ax.twinx()
#df_aqi_covid_2020.plot(x="City", y="cases", ax=ax2, legend=False, color="r")
#ax.figure.legend()
# Out:
# <AxesSubplot:ylabel='cases'>

# %%
plt.figure(figsize=(30,8))
sns.boxplot(y = df_aqi_covid_2020['predicted aqi'], x = df_aqi_covid_2020['county_name'])
# Out:
# <AxesSubplot:xlabel='county_name', ylabel='predicted aqi'>

# %%
plt.figure(figsize=(30,8))
sns.boxplot(y = df_aqi_covid_2020['cases'], x = df_aqi_covid_2020['county_name'])
# Out:
# <AxesSubplot:xlabel='county_name', ylabel='cases'>

# %%
plt.figure(figsize=(30,8))
sns.stripplot(y = df_aqi_covid_2020['predicted aqi'], x = df_aqi_covid_2020['City'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='predicted aqi'>

# %%
plt.figure(figsize=(30,8))
sns.stripplot(y = df_aqi_covid_2020['cases'], x = df_aqi_covid_2020['City'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='cases'>

# %%
plt.figure(figsize=(20,20))
g = sns.FacetGrid(df_aqi_covid_2020, col="City", hue="county_name", col_wrap=4, height=2,)
g.map(sns.scatterplot, "predicted aqi", "cases", alpha=.7)
g.add_legend()

# %%
df_aqi_covid_2020_LA = df_aqi_covid_2020.loc[df_aqi_covid_2020['City'].isin(['Los Angeles'])]
df_aqi_covid_2020_LA = df_aqi_covid_2020_LA.drop(['City'], axis = 1)
df_aqi_covid_2020_HS = df_aqi_covid_2020.loc[df_aqi_covid_2020['City'].isin(['Houston'])]
df_aqi_covid_2020_HS = df_aqi_covid_2020_HS.drop(['City'], axis = 1)
df_aqi_covid_2020_DT = df_aqi_covid_2020.loc[df_aqi_covid_2020['City'].isin(['Detroit'])]
df_aqi_covid_2020_DT = df_aqi_covid_2020_DT.drop(['City'], axis = 1)

# %%
df_aqi_covid_2020_LA.head(-200)
# Out:
#        co   no2    o3  pm10  pm25  predicted aqi        Date  county_name  \
# 9     4.2  26.0   8.8  22.0  42.0     114.199639  2019-12-30  Los Angeles
# 28    7.7  32.5   2.4  23.0  51.0     133.264451  2019-12-31  Los Angeles
# 47    5.5  20.4   6.4  29.0  61.0     154.295933  2020-01-01  Los Angeles
# 67    7.2  24.1  11.2  35.0  61.0     153.537593  2020-01-02  Los Angeles
# 87    7.4  31.5   4.8  30.0  63.0     157.980515  2020-01-03  Los Angeles
# ...   ...   ...   ...   ...   ...            ...         ...          ...
# 8418  2.4   9.3  20.0  16.0  42.0     115.540031  2020-06-27  Los Angeles
# 8490  1.9   3.8  20.0   8.0  15.0      58.152611  2020-06-28  Los Angeles
# 8562  1.8   4.7  20.0  11.0  31.0      92.464447  2020-06-29  Los Angeles
# 8634  2.2  17.6  21.6  20.0  42.0     114.760520  2020-06-30  Los Angeles
# 8706  2.3   7.5  20.0  27.0  42.0     114.370623  2020-07-01  Los Angeles
#
#        cases
# 9        NaN
# 28       NaN
# 47       NaN
# 67       NaN
# ...

# %%
df_aqi_covid_2020_HS.head(-200)
# Out:
#              co        no2    o3       pm10  pm25  predicted aqi        Date  \
# 4      2.454688   7.833333  12.8  18.581864  15.0      57.049511  2019-12-30
# 23     2.454688   7.833333  11.2  18.581864  25.0      78.707734  2019-12-31
# 42     2.454688   7.833333  15.2  18.581864  50.0     132.164510  2020-01-01
# 62     2.454688   7.833333   8.8  18.581864  25.0      78.059449  2020-01-02
# 82     2.454688   7.833333   8.0  18.581864  33.0      95.387848  2020-01-03
# ...         ...        ...   ...        ...   ...            ...         ...
# 15662  6.700000   8.800000  26.4  18.581864  39.0     109.066320  2020-09-30
# 15728  3.400000  10.900000  26.4  18.581864  50.0     132.535497  2020-10-01
# 15729  3.400000  10.900000  26.4  18.581864  50.0     132.535497  2020-10-01
# 15795  2.300000   9.900000  19.2  18.581864  38.0     106.624053  2020-10-02
# 15796  2.300000   9.900000  19.2  18.581864  38.0     106.624053  2020-10-02
#
#       county_name   cases
# ...

# %%
df_aqi_covid_2020_LA.columns = [c.replace(' ', '_') for c in df_aqi_covid_2020_LA.columns]
df_aqi_covid_2020_LA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 9 to 22524
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   co             392 non-null    float64
#  1   no2            392 non-null    float64
#  2   o3             392 non-null    float64
#  3   pm10           392 non-null    float64
#  4   pm25           392 non-null    float64
#  5   predicted_aqi  392 non-null    float64
#  6   Date           392 non-null    object
#  7   county_name    392 non-null    object
#  8   cases          365 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 30.6+ KB

# %%
df_aqi_covid_2020_HS.columns = [c.replace(' ', '_') for c in df_aqi_covid_2020_HS.columns]
df_aqi_covid_2020_HS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 700 entries, 4 to 22496
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   co             700 non-null    float64
#  1   no2            700 non-null    float64
#  2   o3             700 non-null    float64
#  3   pm10           700 non-null    float64
#  4   pm25           700 non-null    float64
#  5   predicted_aqi  700 non-null    float64
#  6   Date           700 non-null    object
#  7   county_name    700 non-null    object
#  8   cases          634 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 54.7+ KB

# %%
df_aqi_covid_2020_DT.columns = [c.replace(' ', '_') for c in df_aqi_covid_2020_DT.columns]
df_aqi_covid_2020_DT.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4638 entries, 2 to 22493
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   co             4638 non-null   float64
#  1   no2            4638 non-null   float64
#  2   o3             4638 non-null   float64
#  3   pm10           4638 non-null   float64
#  4   pm25           4638 non-null   float64
#  5   predicted_aqi  4638 non-null   float64
#  6   Date           4638 non-null   object
#  7   county_name    4638 non-null   object
#  8   cases          4571 non-null   float64
# dtypes: float64(7), object(2)
# memory usage: 362.3+ KB

# %%
plt.figure(figsize=(30,8))
sns.lineplot(data=df_aqi_covid_2020_LA.predicted_aqi, color="g")
ax2 = plt.twinx()
sns.lineplot(data=df_aqi_covid_2020_LA.cases, color="b", ax=ax2)
# Out:
# <AxesSubplot:ylabel='cases'>

# %%
#Create combo chart
fig, ax1 = plt.subplots(figsize=(30,8))
color = 'tab:green'
#bar plot creation
ax1.set_title('Covid and AQI for LA', fontsize=16)
ax1.set_xlabel('Date', fontsize=16)
ax1.set_ylabel('Cases', fontsize=16)
ax1 = sns.barplot(x='Date', y='cases', data = df_aqi_covid_2020_LA, palette='summer')
ax1.tick_params(axis='y')
#specify we want to share the same x-axis
ax2 = ax1.twinx()
color = 'tab:red'
#line plot creation
ax2.set_ylabel('AQI', fontsize=16)
ax2 = sns.lineplot(x='Date', y='predicted_aqi', data = df_aqi_covid_2020_LA, sort=False, color=color)
ax2.tick_params(axis='y', color=color)
#show plot
plt.show()

# %%
#Create combo chart
fig, ax1 = plt.subplots(figsize=(30,8))
color = 'tab:green'
#bar plot creation
ax1.set_title('Covid and AQI for Houston', fontsize=16)
ax1.set_xlabel('Date', fontsize=16)
ax1.set_ylabel('Cases', fontsize=16)
ax1 = sns.barplot(x='Date', y='cases', data = df_aqi_covid_2020_HS, palette='crest')
ax1.tick_params(axis='y')
#specify we want to share the same x-axis
ax2 = ax1.twinx()
color = 'tab:red'
#line plot creation
ax2.set_ylabel('AQI', fontsize=16)
ax2 = sns.lineplot(x='Date', y='predicted_aqi', data = df_aqi_covid_2020_HS, sort=False, color=color)
ax2.tick_params(axis='y', color=color)
#show plot
plt.show()

# %%
#Create combo chart
fig, ax1 = plt.subplots(figsize=(30,8))
color = 'tab:green'
#bar plot creation
ax1.set_title('Covid and AQI for Detroit', fontsize=16)
ax1.set_xlabel('Date', fontsize=16)
ax1.set_ylabel('Cases', fontsize=16)
ax1 = sns.barplot(x='Date', y='cases', data = df_aqi_covid_2020_DT, palette='magma')
ax1.tick_params(axis='y')
#specify we want to share the same x-axis
ax2 = ax1.twinx()
color = 'tab:red'
#line plot creation
ax2.set_ylabel('AQI', fontsize=16)
ax2 = sns.lineplot(x='Date', y='predicted_aqi', data = df_aqi_covid_2020_DT, sort=False, color=color)
ax2.tick_params(axis='y', color=color)
#show plot
plt.show()
